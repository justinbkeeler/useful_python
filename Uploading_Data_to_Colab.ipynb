# %% [markdown]
# <a href="https://colab.research.google.com/github/justinbkeeler/useful_python/blob/main/Uploading_Data_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Option 1: Load local data into Google Colab

# %%
# Load libraries
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()

# Optional io syntax
import io
# Out:
#      <input type="file" id="files-20576ee8-6d7f-4969-b599-00a8ee56032d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20576ee8-6d7f-4969-b599-00a8ee56032d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("titanic.xlsx")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Option 2: Loading data from a cloud repo (e.g. GitHub, OSF, Kaggle) into Google Colab

# %%
# Load libraries
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/justinbkeeler/Datasets/main/titanic.csv"
df2 = pd.read_csv(url)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Option 3a: Loading data from a Google Drive into Google Colab

# %%
# View the current working directory
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# content  drive	sample_data  titanic.xlsx

# %%
# !ls "/content/drive/My Drive/"
# Out:
# 'Colab CO 2023'		    'Evaluations - Student (OBU)'  'Remote Worker Project'
# 'Colab Notebooks'	     Grants			    Sandbox
# 'Conference Presentations'  'Guest Speaker'		   'TCU Faculty Presentation'
# 'Course Material'	     Posters			   'Unpublished Research'
# 'Course Syllabi'	    'Press Releases'		    Workshops
# 'Curriculum Vitae'	     Publications

# %%
# !ls "/content/drive/My Drive/Sandbox"
# Out:
#  iris.csv	    'litbooks (2).csv'	'litbooks (6).csv'   titanic.csv       usedcarsUSA.csv
# 'laptops (1).csv'   'litbooks (3).csv'	 litbooks.csv	     titanic.xlsx
#  laptops.csv	    'litbooks (4).csv'	 nflcombine.xlsx     toughsport.csv
# 'litbooks (1).csv'  'litbooks (5).csv'	 salestarget.csv     toughsport.xlsx

# %%
# Map to '_______' folder within '_____________' folder within 'My Drive' folder
dataset_path = "/content/drive/My Drive/Sandbox"

# %%
print(dataset_path)
# Out:
# /content/drive/My Drive/Sandbox

# %%
# To use the dataset_path, you need to update it to include the .csv file
dataset_path = "/content/drive/My Drive/Sandbox/usedcarsUSA.csv"

# Load the CSV file into a DataFrame
df3 = pd.read_csv(dataset_path)

# Display the DataFrame
df3
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
df3.describe()
# Out:
#         Unnamed: 0         price         year       mileage           lot
# count  2499.000000   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   1249.000000  18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std     721.543484  12116.094936     3.442656  5.970552e+04  2.038772e+05
# min       0.000000      0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%     624.500000  10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    1249.000000  16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    1873.500000  25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    2498.000000  84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %% [markdown]
# Option 3b: Map to a specific folder within Google Drive (beyond the default /content)

# %%
# Import the os library
import os

# %%
# Get the current working directoy
os.getcwd()
# Out:
# '/content'

# %%
# Change to a different folder using "os.chdir"
path_to_mydataset = "/content/drive/My Drive/Sandbox"
os.chdir(path_to_mydataset)

# %%
# Confirm a directory remapping to a different folder
os.getcwd()
# Out:
# '/content/drive/My Drive/Sandbox'

# %%
# View list of files with "!ls" in the mapped destination
# !ls
# Out:
#  iris.csv	    'litbooks (2).csv'	'litbooks (6).csv'   titanic.csv       usedcarsUSA.csv
# 'laptops (1).csv'   'litbooks (3).csv'	 litbooks.csv	     titanic.xlsx
#  laptops.csv	    'litbooks (4).csv'	 nflcombine.xlsx     toughsport.csv
# 'litbooks (1).csv'  'litbooks (5).csv'	 salestarget.csv     toughsport.xlsx

# %%
df5 = pd.read_csv("toughsport.csv")
df5
# Out:
#                                   SPORT   END   STR   PWR   SPD   AGI    FLX  \
# 0                                Boxing  8.63  8.13  8.63  6.38  6.25   4.38
# 1                            Ice Hockey  7.25  7.13  7.88  7.75  7.63   4.88
# 2                              Football  5.38  8.63  8.13  7.13  6.38   4.38
# 3                            Basketball  7.38  6.25  6.50  7.25  8.13   5.63
# 4                             Wrestling  6.63  8.38  7.13  5.13  6.38   7.50
# 5                          Martial Arts  5.00  5.88  7.75  6.38  6.00   7.00
# 6                                Tennis  7.25  5.13  7.13  6.75  7.75   5.63
# 7                            Gymnastics  5.38  6.13  6.63  5.00  6.38  10.00
# 8                     Baseball/Softball  4.63  5.75  7.63  6.50  6.75   4.75
# 9                                Soccer  7.75  4.50  5.13  7.25  8.25   4.75
# 10                       Skiing: Alpine  5.13  5.25  6.00  7.38  6.13   5.63
# ...

# %%
df5.describe()
# Out:
#              END        STR        PWR        SPD        AGI        FLX  \
# count  60.000000  60.000000  60.000000  60.000000  60.000000  60.000000
# mean    5.077667   5.169000   5.509167   4.815000   4.765000   4.723167
# std     2.094217   1.715357   1.980397   2.266403   1.927273   1.704369
# min     1.000000   1.000000   1.250000   0.630000   1.000000   1.130000
# 25%     3.500000   3.880000   4.097500   3.000000   3.437500   3.847500
# 50%     4.630000   5.190000   5.690000   5.130000   4.755000   4.750000
# 75%     6.660000   6.130000   7.130000   6.410000   6.380000   5.532500
# max     9.630000   9.250000   9.750000   9.880000   8.250000  10.000000
#
#              NER        DUR        HAN        ANA      TOTAL       RANK
# count  60.000000  60.000000  60.000000  60.000000  60.000000  60.000000
# mean    4.614833   4.612833   4.954833   4.767333  48.983333  30.400000
# std     2.442645   1.882102   1.966328   1.576830  12.170519  17.473661
# ...
